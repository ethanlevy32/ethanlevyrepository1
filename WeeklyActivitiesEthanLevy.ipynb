# %% [markdown]
# <a href="https://colab.research.google.com/github/ethanlevy32/ethanlevyrepository1/blob/main/WeeklyActivitiesEthanLevy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Week 3 Activity

# %% [markdown]
# Design a simple numerical calculator. The user provides three inputs: two numbers and the operator. The program will print the output on the screen.

# %%
num1 = float(input("Enter a number:"))
num2 = float(input("Enter another number:"))
operation = input("Enter an operation (+, -, *, /):")

if operation == "+":
    print(num1 + num2)
elif operation == "-":
    print(num1 - num2)
elif operation == "*":
    print(num1 * num2)
elif operation == "/":
    print(num1 / num2)
else: print("An error occurred during calculation. You can't divide by 0.")
# Out:
# Enter a number:19
# Enter another number:45
# Enter an operation (+, -, *, /):*
# 855.0

# %% [markdown]
# Week 5 Activity

# %% [markdown]
# Parking garage charges \$5 plus $2.50 each hour. Write a program that shows the number of hours parked and the corresponding fee side by side from 1 to 8 hours.
# Also do a minimum and maximum fee of 10 and 20 respectively.

# %%
for hour in range(1,9,1):
  fee= 5 +2.5*hour
  if fee<10:
    fee=10.0
  elif fee>20:
    fee=20.0
  print(hour, fee)
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %% [markdown]
# At a movie theater, tickets are \$10. Without advertisng 20 people attend. More people come depending on marketing: Additional= 2 x advertising dollars ^1/2. Theres also a fixed cost to run the theater of \$200.

# %%
import math

ticket= 10
init_attendees= 20
fixed_cost = 200

print("Ad Profit")

for Ad in range(0,201,25):
  revenue= (init_attendees + 2 * round(math.sqrt(Ad)))*10
  costs= fixed_cost + Ad
  profit= revenue-costs
  print(Ad, profit)
# Out:
# Ad Profit
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %% [markdown]
# While Loops:

# %%
hour = 1
while hour < 9:
  fee= 5 +2.5*hour
  if fee<10:
    fee=10.0
  elif fee>20:
    fee=20.0
  print(hour, fee)
  hour += 1
# Out:
# 1 10.0
# 2 10.0
# 3 12.5
# 4 15.0
# 5 17.5
# 6 20.0
# 7 20.0
# 8 20.0

# %%
import math

ticket= 10
init_attendees= 20
fixed_cost = 200

print("Ad Profit")

Ad = 0
while Ad < 201:
  revenue= (init_attendees + 2 * round(math.sqrt(Ad)))*10
  costs= fixed_cost + Ad
  profit= revenue-costs
  print(Ad, profit)
  Ad += 25
# Out:
# Ad Profit
# 0 0
# 25 75
# 50 90
# 75 105
# 100 100
# 125 95
# 150 90
# 175 85
# 200 80

# %% [markdown]
# Week 6 Activity

# %% [markdown]
# Rock paper scissors activity

# %%
import random #

play = input("Do you want to play (y/n)")


while play == "y":
  player_move= (input("Rock, paper, or scissors?"))
  computer_move= (random.choice(['rock', 'paper', 'scissors']))

  if player_move == computer_move:
    print("Draw")
  elif player_move == "rock" and computer_move == "scissors":
    print("You win!")
  elif player_move == "rock" and computer_move == "paper":
    print("You lose.")
  elif player_move == "paper" and computer_move == "rock":
    print("You win!")
  elif player_move == "paper" and computer_move == "scissors":
    print("You lose.")
  elif player_move == "scissors" and computer_move == "paper":
    print("You win!")
  elif player_move == "scissors" and computer_move == "rock":
    print("You lose.")

  play = input("Do you want to play again? (y/n)")
# Out:
# Do you want to play (y/n)y
# Rock, paper, or scissors?rock
# You lose.
# Do you want to play again? (y/n)y
# Rock, paper, or scissors?rock
# Draw
# Do you want to play again? (y/n)n

# %% [markdown]
# Week 7 Assignments:

# %%
while num != 0:
  num = float(input("Enter a number: "))
  if num != 0:
    print(f"You entered: {num}")
  elif num == 0:
    print("Program stopped. You entered 0.")
# Out:
# Enter a number: 3
# You entered: 3.0
# Enter a number: 4
# You entered: 4.0
# Enter a number: 5
# You entered: 5.0
# Enter a number: 0
# Program stopped. You entered 0.

# %%
numbers = []

while True:
  num = float(input("Enter a number: "))
  if num == 0:
    break
  numbers.append(num)
numbers.sort(reverse=True)
print(numbers)
# Out:
# Enter a number: 3
# Enter a number: 4
# Enter a number: 6
# Enter a number: 1
# Enter a number: 0
# [6.0, 4.0, 3.0, 1.0]

# %%
weights =[10,9.9,10.1, 10.05]

print(sum (weights) / (len(weights))) # avg weight
print(max(weights)) # max weight
print(min(weights)) # min weight
# Out:
# 10.0125
# 10.1
# 9.9

# %%
products = {
    "P-01": 9.95,
    "P-02": 10.50
}

id = input("Enter a product ID (e.g., P-01): ")

if id in products:
    print(products[id])
else:
    print(f"Product '{product_id}' not found.")
# Out:
# Enter a product ID (e.g., P-01): P-05
# Product 'P-01' not found.

# %%
names = {}

while True:
  name = input("Give a name:")
  if name == "":
    break

  if name in names:
    names [name] += 1
  else:
    names[name] = 1

print(names)
# Out:
# Give a name:bob
# Give a name:john
# Give a name:ethan
# Give a name:
# {'bob': 1, 'john': 1, 'ethan': 1}

# %% [markdown]
# Week 9 Assignments

# %% [markdown]
# Parking garage problem. Wrap the conditional into a function that takes as input parameter the number of parking hours and returns the fee. Bonus: Use a second main() function where the user dynamically assigns the number of hours from the keyboard. This function takes no input parameters, but calls calcFee and returns the fee.

# %%
def calcFee(hour):
  fee= 5 +2.5*hour
  if fee<10:
    fee=10.0
  elif fee>20:
    fee=20.0
  print(fee)

def main():
  hour = int(input("Enter the number of parking hours:"))
  calcFee(hour)

main()
# Out:
# Enter the number of parking hours:5
# 17.5
